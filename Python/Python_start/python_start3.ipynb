# %% [markdown]
# ## 조건문 if  ( if 조건:)
# * ####   주의할점
#     1. 주의 파이썬에서는 라인의 끝을 알리는 세미콜론(;)을 쓰지 않는데 반복문,제어문,함수 등에서는 콜론(:)으로 조건을 구분짓는다
#     2. (tab) 실행할것
#     3. 같다는=이게아니라 ==
# * #### 조건
# 조건에는 and not or >= 다 넣을 수 있다 if abc>=19 and abc<=22; 이런식으로  가능하다
# * #### else
# `if abc>=19 and abc<=22;`
# `	abc+=2`           #(+= 는 왼쪽변수에 오른쪽더하고 그 결과를 왼쪽변수에 할당 여기서도 =는 오른쪽)
# `else;`
# `	abc+=100`
# `elif(else+if)`
# `if abc>=19 and abc<=22;`
# `	abc+=2`
# `elif abc>22;`
# `	abc+=29`
# `else;`
# `	abc+=100`
# * #### 조건문안에 조건문
# `cash=int(input("현금은?"))`
# `if cash>10000;`
# `    print("레스토랑")`
# `else;`
# `	if cash>5000;`
# `		print("밥집")`
# `		if cash>7000;`
# `			print("pc방")`
# `		elif cash cash>6000;`
# `			print('카페')`
# `	else;`
# `		print('집이나가셈')`
# tab을 잘 맞춰야한다
# ## 반복문(빡)
# * #### for문
#     * 형태
# `fot 변수(사용될수도있는) in 리스트:`
# `	print( $#*)`
# `for 변수(사용될수도있는) in range(반복횟수n 0-n-1):`
# `	실행코드`
#     * 예
# `sum=0`
# `for i in range(1,11); #1~10`
# `	sum+=i`
# * #### while문
# while~하는 동안 끝나도 조건맞으면 계속 실행
# 주의 for문과 다르게 여기서 i는 미리 정의를 하고 써야한다
#     * 예
# `i=0`
# `while i <=3;`
# `	print(i)`
# `	i+=1`
# `>>> 0,1,2,3 이고 i는4`
# `i=0`
# `while i <=3;`
# `	i+=1`
# `	print(i)`
# `>>> 1,2,3,4 이고 i는4`
#     * while 1:
#     print("roof")
#     여기에 0이나 False만 아니면 다 루프임<br>
# ex)
# `name=' '#이게 정말 중요함`
# `while name!="hayun":`  ## while조건에 원하는 조건의 역을 써주는 것
# `	print("안뇽 hayun나와")`
# `	name=input("너이름뭐야?")`
# `print("드디어찾았다")`
